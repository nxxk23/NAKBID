# %% [markdown]
# <a href="https://colab.research.google.com/github/nxxk23/NAKBID/blob/main/NINK/mergeforgraph.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
data = pd.read_csv('/content/drive/MyDrive/AIEngineer/contrast/tmt/data center/for_GG.csv')
data
# Out:
#           TPID    TPUID     GPID  \
# 0      1323902  1323918   958607
# 1      1323994  1324000  1323973
# 2      1324059  1324063   484701
# 3      1323109  1324102  1323081
# 4      1324160  1324173   820507
# ...        ...      ...      ...
# 33339  1305320  1305377  1305308
# 33340  1309107  1286845  1309078
# 33341  1286799  1286845  1286775
# 33342  1314405  1314446   278985
# 33343  1313266  1314446   279038
#
#                                                      FSN  CHANGEDATE
# 0      alogliptin 25 mg + pioglitazone 30 mg film-coa...    20150910
# 1      ibuprofen 300 mg/100 mL + paracetamol 1 g/100 ...    20250215
# 2                 azilsartan medoxomil 40 mg tablet (GP)    20130805
# 3      cytomegalovirus immunoglobulin 100 iu/1 mL sol...    20250215
# 4      boric acid 1.24 g/100 mL + sodium borate 20 mg...    20140705
# ...                                                  ...         ...
# 33339  recombinant respiratory syncytial virus (RSV) ...    20240817
# ...

# %%
a = pd.read_excel('/content/drive/MyDrive/AIEngineer/contrast/tmt/Concept/TPU20250217.xlsx')
a.head()
# Out:
#    TMTID(TPU)                                                FSN  \
# 0     1049236  0.0001% DPCP (F 12249) (diphenylcyclopropenone...
# 1     1049289  0.0005% DPCP (F 12249) (diphenylcyclopropenone...
# 2     1049338  0.001% DPCP (F 12249) (diphenylcyclopropenone ...
# 3     1049386  0.005% DPCP (F 12249) (diphenylcyclopropenone ...
# 4     1270858  0.01% ATROPINE EYE DROP 10 ML (M 13756) (atrop...
#
#                  MANUFACTURER  CHANGEDATE
# 0            สถาบันโรคผิวหนัง    20190103
# 1            สถาบันโรคผิวหนัง    20190103
# 2            สถาบันโรคผิวหนัง    20190103
# 3            สถาบันโรคผิวหนัง    20190103
# 4  จุฬาลงกรณ์ สภากาชาดไทย,รพ.    20230617

# %%
all = pd.read_csv('/content/drive/MyDrive/AIEngineer/contrast/tmt/all.csv')
all.head(2)
# Out:
#    TMTID(TP)  TMTID(TPU)  TMTID(GP)  TMTID(VTM)  TMTID(SUBS)  TMTID(GPU)  \
# 0    1323902     1323918     958607      958551       230434      958611
# 1    1323902     1323918     958607      958551       958533      958611
#
#                                               GPNAME  \
# 0  alogliptin 25 mg + pioglitazone 30 mg film-coa...
# 1  alogliptin 25 mg + pioglitazone 30 mg film-coa...
#
#                                               TPNAME  \
# 0  OSENI 25 MG/30 MG TABLETS (CELLTRION PHARM, KO...
# 1  OSENI 25 MG/30 MG TABLETS (CELLTRION PHARM, KO...
#
#                                              GPUNAME  \
# 0  alogliptin 25 mg + pioglitazone 30 mg film-coa...
# 1  alogliptin 25 mg + pioglitazone 30 mg film-coa...
#
#                                              TPUNAME  \
# 0  OSENI 25 MG/30 MG TABLETS (CELLTRION PHARM, KO...
# 1  OSENI 25 MG/30 MG TABLETS (CELLTRION PHARM, KO...
#
#                            VTMNAME             SUBSNAME
# ...

# %%
all.nunique()
# Out:
# TMTID(TP)      30871
# TMTID(TPU)     33327
# TMTID(GP)       8219
# TMTID(VTM)      2864
# TMTID(SUBS)     2278
# TMTID(GPU)     10671
# GPNAME          8219
# TPNAME         30871
# GPUNAME        10671
# TPUNAME        33327
# VTMNAME         2864
# SUBSNAME        2278
# dtype: int64

# %%
all.iloc[['16257','52115']]['TPNAME']
# Out:
#        TMTID(TP)  TMTID(TPU)  TMTID(GP)  TMTID(VTM)  TMTID(SUBS)  TMTID(GPU)  \
# 16257     466024      466030     747132      747121       665824      747145
# 52115     718674      718688     747132      747121       665824      747145
#
#                                GPNAME  \
# 16257  paracetamol 500 mg tablet (GP)
# 52115  paracetamol 500 mg tablet (GP)
#
#                                                   TPNAME  \
# 16257  TYLENOL 500 (โอลิค) (paracetamol 500 mg) table...
# 52115  ADULT'S TYLENOL 500 (โอลิค) (paracetamol 500 m...
#
#                                          GPUNAME  \
# 16257  paracetamol 500 mg tablet, 1 tablet (GPU)
# 52115  paracetamol 500 mg tablet, 1 tablet (GPU)
#
#                                                  TPUNAME            VTMNAME  \
# 16257  TYLENOL 500 (โอลิค) (paracetamol 500 mg) table...  paracetamol (VTM)
# 52115  ADULT'S TYLENOL 500 (โอลิค) (paracetamol 500 m...  paracetamol (VTM)
#
#                  SUBSNAME
# ...

# %%
all[(all['TPNAME'].str.contains('sara', case=False)) & (all['SUBSNAME'].str.contains('paracetamol'))]
# Out:
#        TMTID(TP)  TMTID(TPU)  TMTID(GP)  TMTID(VTM)  TMTID(SUBS)  TMTID(GPU)  \
# 14811     437738      437740     228445      747121       665824      228450
# 14812     437755      437764     747132      747121       665824      747145
# 14813     437772      437786     227883      955717       665824      227896
# 14816     437793      437803     303324      748231       665824      303330
# 14821     437819      437826     240237      240228       665824      240244
# 14822     437835      437842     228445      747121       665824      228450
# 14823     437857      437861     747132      747121       665824      747145
# 32395     541392      541407     574344      574337       665824      541363
# 32396     541392      541407     574344      574337       665824      574359
# 35083     574080      574098     573977      747121       665824      573983
# 35084     574080      574098     573977      747121       665824      574079
# ...

# %%
matches
# Out:
# Empty DataFrame
# Columns: [TMTID(TP), TMTID(TPU), TMTID(GP), TMTID(VTM), TMTID(SUBS), TMTID(GPU), GPNAME, TPNAME, GPUNAME, TPUNAME, VTMNAME, SUBSNAME]
# Index: []

# %%
print(all['GPNAME'].iloc[0])
print(all['GPUNAME'].iloc[0])
# Out:
# alogliptin 25 mg + pioglitazone 30 mg film-coated tablet (GP)
# alogliptin 25 mg + pioglitazone 30 mg film-coated tablet, 1 tablet (GPU)

# %%
print(all['GPNAME'].iloc[0])
print(all['TPNAME'].iloc[0])
# Out:
# alogliptin 25 mg + pioglitazone 30 mg film-coated tablet (GP)
# OSENI 25 MG/30 MG TABLETS (CELLTRION PHARM, KOREA) (alogliptin 25 mg + pioglitazone 30 mg) film-coated tablet (TP)

# %%
all.nunique()
# Out:
# TMTID(TP)      30871
# TMTID(TPU)     33327
# TMTID(GP)       8219
# TMTID(VTM)      2864
# TMTID(SUBS)     2278
# TMTID(GPU)     10671
# GPNAME          8219
# TPNAME         30871
# GPUNAME        10671
# TPUNAME        33327
# VTMNAME         2864
# SUBSNAME        2278
# dtype: int64
